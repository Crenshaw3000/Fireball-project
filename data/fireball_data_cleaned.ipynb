# %%
import pandas as pd
import numpy as np
import datetime
import json

# %%
#Read file and set the column index 
df = pd.read_csv('cneos_fireball_data.csv')
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# ...

# %%
df.dtypes
# Out:
# Peak Brightness Date/Time (UT)          object
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# dtype: object

# %%
#Take the log of Caculated Total Impact Energry
df['energy']= np.log(df['Calculated Total Impact Energy (kt)'])
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# ...

# %%
del df['Altitude (km)']
del df['Velocity (km/s)']
del df['vx']
del df['vy']
del df['vz']
del df['Total Radiated Energy (J)']
del df['Calculated Total Impact Energy (kt)']

# %%
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)    energy
# 0              2022-09-04 03:54:55           20.0N           165.9E -2.453408
# 1              2020-01-17 21:29:49           19.4N            66.0W -1.237874
# 2              2005-05-07 09:31:44           75.8S           163.7E -2.385967
# 3              2005-10-26 21:30:47           36.3S            80.5W -0.916291
# 4              2003-04-13 17:58:41           14.8N            64.5E -0.693147
# ..                             ...             ...              ...       ...
# 927            2006-04-25 18:46:53             NaN              NaN -2.617296
# 928            2005-04-16 10:40:38             NaN              NaN -2.617296
# 929            2003-09-21 07:40:00             NaN              NaN -2.617296
# 930            2002-03-18 14:44:57           60.4S           120.5W -2.617296
# 931            2000-06-23 09:03:42           69.2N            44.0W -2.617296
#
# [932 rows x 4 columns]

# %%
#rename columns
df.rename(columns = {'Peak Brightness Date/Time (UT)':'date', 'Latitude (deg.)':'latitude', 'Longitude (deg.)':'longitude'}, inplace = True)
df
# Out:
#                     date latitude longitude    energy
# 0    2022-09-04 03:54:55    20.0N    165.9E -2.453408
# 1    2020-01-17 21:29:49    19.4N     66.0W -1.237874
# 2    2005-05-07 09:31:44    75.8S    163.7E -2.385967
# 3    2005-10-26 21:30:47    36.3S     80.5W -0.916291
# 4    2003-04-13 17:58:41    14.8N     64.5E -0.693147
# ..                   ...      ...       ...       ...
# 927  2006-04-25 18:46:53      NaN       NaN -2.617296
# 928  2005-04-16 10:40:38      NaN       NaN -2.617296
# 929  2003-09-21 07:40:00      NaN       NaN -2.617296
# 930  2002-03-18 14:44:57    60.4S    120.5W -2.617296
# 931  2000-06-23 09:03:42    69.2N     44.0W -2.617296
#
# [932 rows x 4 columns]

# %%
#drop empty values in place
df.dropna(inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of                     date latitude longitude    energy
# 0    2022-09-04 03:54:55    20.0N    165.9E -2.453408
# 1    2020-01-17 21:29:49    19.4N     66.0W -1.237874
# 2    2005-05-07 09:31:44    75.8S    163.7E -2.385967
# 3    2005-10-26 21:30:47    36.3S     80.5W -0.916291
# 4    2003-04-13 17:58:41    14.8N     64.5E -0.693147
# ..                   ...      ...       ...       ...
# 924  2008-08-12 11:44:10    11.6S    175.0W -2.617296
# 925  2008-04-30 01:18:38    33.6S     35.1W -2.617296
# 926  2008-02-19 13:30:30    48.9N    119.8W -2.617296
# 930  2002-03-18 14:44:57    60.4S    120.5W -2.617296
# 931  2000-06-23 09:03:42    69.2N     44.0W -2.617296
#
# [742 rows x 4 columns]>

# %%
df.dtypes
# Out:
# date          object
# latitude      object
# longitude     object
# energy       float64
# dtype: object

# %%
df.describe()
# Out:
#            energy
# count  742.000000
# mean    -1.257346
# std      1.201357
# min     -2.617296
# 25%     -2.185522
# 50%     -1.514128
# 75%     -0.739233
# max      6.086775

# %%
df.describe(include = 'object')
# Out:
#                        date latitude longitude
# count                   742      742       742
# unique                  742      572       672
# top     2022-09-04 03:54:55    28.0N     64.6W
# freq                      1        4         4

# %%
my_dict=df.to_dict( orient="records")
print(my_dict)
# Out:
# [{'date': '2022-09-04 03:54:55', 'latitude': '20.0N', 'longitude': '165.9E', 'energy': -2.4534079827286295}, {'date': '2020-01-17 21:29:49', 'latitude': '19.4N', 'longitude': '66.0W', 'energy': -1.2378743560016174}, {'date': '2005-05-07 09:31:44', 'latitude': '75.8S', 'longitude': '163.7E', 'energy': -2.385966701933097}, {'date': '2005-10-26 21:30:47', 'latitude': '36.3S', 'longitude': '80.5W', 'energy': -0.916290731874155}, {'date': '2003-04-13 17:58:41', 'latitude': '14.8N', 'longitude': '64.5E', 'energy': -0.6931471805599453}, {'date': '2014-01-08 17:05:34', 'latitude': '1.3S', 'longitude': '147.6E', 'energy': -2.2072749131897207}, {'date': '2022-06-26 20:16:26', 'latitude': '69.7S', 'longitude': '164.7E', 'energy': -1.5606477482646683}, {'date': '2009-10-08 02:57:00', 'latitude': '4.2S', 'longitude': '120.6E', 'energy': 3.4965075614664802}, {'date': '2021-01-25 03:01:37', 'latitude': '38.5N', 'longitude': '47.6W', 'energy': -1.4696759700589417}, {'date': '2019-12-06 10:19:57', 'l
# ...
