# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('cneos_fireball_data.csv', index_col="Peak Brightness Date/Time (UT)")
df
# Out:
#                                Latitude (deg.) Longitude (deg.)  \
# Peak Brightness Date/Time (UT)
# 2022-09-04 03:54:55                      20.0N           165.9E
# 2020-01-17 21:29:49                      19.4N            66.0W
# 2005-05-07 09:31:44                      75.8S           163.7E
# 2005-10-26 21:30:47                      36.3S            80.5W
# 2003-04-13 17:58:41                      14.8N            64.5E
# ...                                        ...              ...
# 2006-04-25 18:46:53                        NaN              NaN
# 2005-04-16 10:40:38                        NaN              NaN
# 2003-09-21 07:40:00                        NaN              NaN
# 2002-03-18 14:44:57                      60.4S           120.5W
# 2000-06-23 09:03:42                      69.2N            44.0W
#
#                                 Altitude (km)  Velocity (km/s)    vx    vy  \
# Peak Brightness Date/Time (UT)
# ...

# %%
df.dtypes
# Out:
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# dtype: object

# %%
del df.drop(colums=['Altitude (km)'])
# Out:
#   File "/var/folders/sy/62ttby5x7y1fqxmw60tg_lj80000gn/T/ipykernel_44084/1680013787.py", line 1
#     del df.drop(colums=['Altitude(km)'])
#         ^
# SyntaxError: cannot delete function call
