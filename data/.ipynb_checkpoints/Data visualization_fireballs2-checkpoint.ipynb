# %%
import pandas as pd
import numpy as np
import datetime

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('cneos_fireball_data.csv')
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# 1             14.5             15.5 -13.2   8.1  1.2
# 2             15.2             16.6   9.6  -9.7  9.4
# 3             16.7              NaN   NaN   NaN  NaN
# 4             17.0              NaN   NaN   NaN  NaN
# ..             ...              ...   ...   ...  ...
# 927            NaN              NaN   NaN   NaN  NaN
# 928            NaN              NaN   NaN   NaN  NaN
# 929            NaN              NaN   NaN   NaN  NaN
# 930            NaN              NaN   NaN   NaN  NaN
# 931            NaN              NaN   NaN   NaN  NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0                 2.400000e+10                                0.086
# 1                 9.700000e+10                                0.290
# 2                 2.600000e+10                                0.092
# 3                 1.380000e+11                                0.400
# 4                 1.750000e+11                                0.500
# ..                         ...                                  ...
# 927               2.000000e+10                                0.073
# 928               2.000000e+10                                0.073
# 929               2.000000e+10                                0.073
# 930               2.000000e+10                                0.073
# 931               2.000000e+10                                0.073
#
# [932 rows x 10 columns]

# %%
df.dtypes
# Out:
# Peak Brightness Date/Time (UT)          object
# Latitude (deg.)                         object
# Longitude (deg.)                        object
# Altitude (km)                          float64
# Velocity (km/s)                        float64
# vx                                     float64
# vy                                     float64
# vz                                     float64
# Total Radiated Energy (J)              float64
# Calculated Total Impact Energy (kt)    float64
# dtype: object

# %%
df.describe()
# Out:
#        Altitude (km)  Velocity (km/s)          vx         vy          vz  \
# count     474.000000       278.000000  278.000000  278.00000  278.000000
# mean       36.071941        17.875540   -0.155755   -2.01223   -0.876619
# std        10.476231         5.599553   10.960195   11.05490   10.442363
# min        14.000000         9.800000  -35.400000  -43.50000  -31.200000
# 25%        29.450000        14.100000   -8.500000   -9.97500   -9.175000
# 50%        34.650000        16.900000   -0.850000   -2.90000    0.000000
# 75%        40.650000        19.975000    8.475000    5.45000    6.675000
# max        74.000000        49.000000   27.800000   31.20000   27.000000
#
#        Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# count               9.320000e+02                           932.000000
# mean                7.573927e+11                             1.230736
# std                 1.239195e+13                            14.675072
# min                 2.000000e+10                             0.073000
# 25%                 3.200000e+10                             0.110000
# 50%                 6.300000e+10                             0.200000
# 75%                 1.452500e+11                             0.420000
# max                 3.750000e+14                           440.000000

# %%
df.describe(include = 'object')
# Out:
#        Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)
# count                             932             742              742
# unique                            932             572              672
# top               2022-09-04 03:54:55           28.0N            64.6W
# freq                                1               4                4

# %%
#Take the log of Caculated Total Impact Energry
df['Log Impact Energy']= np.log(df['Calculated Total Impact Energy (kt)'])
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# 1             14.5             15.5 -13.2   8.1  1.2
# 2             15.2             16.6   9.6  -9.7  9.4
# 3             16.7              NaN   NaN   NaN  NaN
# 4             17.0              NaN   NaN   NaN  NaN
# ..             ...              ...   ...   ...  ...
# 927            NaN              NaN   NaN   NaN  NaN
# 928            NaN              NaN   NaN   NaN  NaN
# 929            NaN              NaN   NaN   NaN  NaN
# 930            NaN              NaN   NaN   NaN  NaN
# 931            NaN              NaN   NaN   NaN  NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 1                 9.700000e+10                                0.290
# 2                 2.600000e+10                                0.092
# 3                 1.380000e+11                                0.400
# 4                 1.750000e+11                                0.500
# ..                         ...                                  ...
# 927               2.000000e+10                                0.073
# 928               2.000000e+10                                0.073
# 929               2.000000e+10                                0.073
# 930               2.000000e+10                                0.073
# 931               2.000000e+10                                0.073
#
#      Log Impact Energy
# 0            -2.453408
# 1            -1.237874
# 2            -2.385967
# 3            -0.916291
# 4            -0.693147
# ..                 ...
# 927          -2.617296
# 928          -2.617296
# 929          -2.617296
# 930          -2.617296
# 931          -2.617296
#
# [932 rows x 11 columns]

# %%
#Parse year out of Peak Brightness Date/Time colument to make a Year column
df['Year'] = pd.to_datetime(df['Peak Brightness Date/Time (UT)']).dt.year
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# 1             14.5             15.5 -13.2   8.1  1.2
# 2             15.2             16.6   9.6  -9.7  9.4
# 3             16.7              NaN   NaN   NaN  NaN
# 4             17.0              NaN   NaN   NaN  NaN
# ..             ...              ...   ...   ...  ...
# 927            NaN              NaN   NaN   NaN  NaN
# 928            NaN              NaN   NaN   NaN  NaN
# 929            NaN              NaN   NaN   NaN  NaN
# 930            NaN              NaN   NaN   NaN  NaN
# 931            NaN              NaN   NaN   NaN  NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 1                 9.700000e+10                                0.290
# 2                 2.600000e+10                                0.092
# 3                 1.380000e+11                                0.400
# 4                 1.750000e+11                                0.500
# ..                         ...                                  ...
# 927               2.000000e+10                                0.073
# 928               2.000000e+10                                0.073
# 929               2.000000e+10                                0.073
# 930               2.000000e+10                                0.073
# 931               2.000000e+10                                0.073
#
#      Log Impact Energy  Year
# 0            -2.453408  2022
# 1            -1.237874  2020
# 2            -2.385967  2005
# 3            -0.916291  2005
# 4            -0.693147  2003
# ..                 ...   ...
# 927          -2.617296  2006
# 928          -2.617296  2005
# 929          -2.617296  2003
# 930          -2.617296  2002
# 931          -2.617296  2000
#
# [932 rows x 12 columns]

# %%
#View counts of the Years
df['Year'].value_counts()
# Out:
# 2015    45
# 2005    45
# 2019    42
# 2020    41
# 2018    39
# 2004    39
# 2003    37
# 2000    37
# 2006    37
# 2012    37
# 2008    37
# 2010    36
# 2022    34
# 2009    34
# 2016    33
# 1996    33
# 2014    33
# 2021    32
# 2011    31
# 1999    30
# 2002    29
# 2017    29
# 2013    24
# 2007    23
# 2001    22
# 1995    21
# 1997    21
# 1994    13
# 1998    13
# 1993     2
# 1988     1
# 1990     1
# 1991     1
# Name: Year, dtype: int64

# %%
#add Counts to dataframe and labeled the column Events_by_year
df['Year'] = pd.to_datetime(df['Peak Brightness Date/Time (UT)']).dt.year
df['Events_by_year'] = df.groupby('Year')['Year'].transform('count')
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)    vx    vy   vz  \
# 0             14.0             21.9  18.4 -11.4 -3.5
# 1             14.5             15.5 -13.2   8.1  1.2
# 2             15.2             16.6   9.6  -9.7  9.4
# 3             16.7              NaN   NaN   NaN  NaN
# 4             17.0              NaN   NaN   NaN  NaN
# ..             ...              ...   ...   ...  ...
# 927            NaN              NaN   NaN   NaN  NaN
# 928            NaN              NaN   NaN   NaN  NaN
# 929            NaN              NaN   NaN   NaN  NaN
# 930            NaN              NaN   NaN   NaN  NaN
# 931            NaN              NaN   NaN   NaN  NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 1                 9.700000e+10                                0.290
# 2                 2.600000e+10                                0.092
# 3                 1.380000e+11                                0.400
# 4                 1.750000e+11                                0.500
# ..                         ...                                  ...
# 927               2.000000e+10                                0.073
# 928               2.000000e+10                                0.073
# 929               2.000000e+10                                0.073
# 930               2.000000e+10                                0.073
# 931               2.000000e+10                                0.073
#
#      Log Impact Energy  Year  Events_by_year
# 0            -2.453408  2022              34
# 1            -1.237874  2020              41
# 2            -2.385967  2005              45
# 3            -0.916291  2005              45
# 4            -0.693147  2003              37
# ..                 ...   ...             ...
# 927          -2.617296  2006              37
# 928          -2.617296  2005              45
# 929          -2.617296  2003              37
# 930          -2.617296  2002              29
# 931          -2.617296  2000              37
#
# [932 rows x 13 columns]

# %%
df.describe()
# Out:
#        Altitude (km)  Velocity (km/s)          vx         vy          vz  \
# count     474.000000       278.000000  278.000000  278.00000  278.000000
# mean       36.071941        17.875540   -0.155755   -2.01223   -0.876619
# std        10.476231         5.599553   10.960195   11.05490   10.442363
# min        14.000000         9.800000  -35.400000  -43.50000  -31.200000
# 25%        29.450000        14.100000   -8.500000   -9.97500   -9.175000
# 50%        34.650000        16.900000   -0.850000   -2.90000    0.000000
# 75%        40.650000        19.975000    8.475000    5.45000    6.675000
# max        74.000000        49.000000   27.800000   31.20000   27.000000
#
#        Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# count               9.320000e+02                           932.000000
# mean                7.573927e+11                             1.230736
# std                 1.239195e+13                            14.675072
# min                 2.000000e+10                             0.073000
# 25%                 3.200000e+10                             0.110000
# 50%                 6.300000e+10                             0.200000
# 75%                 1.452500e+11                             0.420000
# max                 3.750000e+14                           440.000000
#
#        Log Impact Energy         Year  Events_by_year
# count         932.000000   932.000000      932.000000
# mean           -1.358434  2009.048283       33.948498
# std             1.135432     8.070236        7.616586
# min            -2.617296  1988.000000        1.000000
# 25%            -2.207275  2003.000000       31.000000
# 50%            -1.609438  2009.000000       36.000000
# 75%            -0.867501  2016.000000       39.000000
# max             6.086775  2022.000000       45.000000

# %%
del df['vx']
del df['vy']
del df['vz']

# %%
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             14.0             21.9               2.400000e+10
# 1             14.5             15.5               9.700000e+10
# 2             15.2             16.6               2.600000e+10
# 3             16.7              NaN               1.380000e+11
# 4             17.0              NaN               1.750000e+11
# ..             ...              ...                        ...
# 927            NaN              NaN               2.000000e+10
# 928            NaN              NaN               2.000000e+10
# 929            NaN              NaN               2.000000e+10
# 930            NaN              NaN               2.000000e+10
# 931            NaN              NaN               2.000000e+10
#
#      Calculated Total Impact Energy (kt)  Log Impact Energy  Year  \
# 0                                  0.086          -2.453408  2022
# 1                                  0.290          -1.237874  2020
# 2                                  0.092          -2.385967  2005
# 3                                  0.400          -0.916291  2005
# 4                                  0.500          -0.693147  2003
# ..                                   ...                ...   ...
# 927                                0.073          -2.617296  2006
# 928                                0.073          -2.617296  2005
# 929                                0.073          -2.617296  2003
# 930                                0.073          -2.617296  2002
# 931                                0.073          -2.617296  2000
#
#      Events_by_year
# 0                34
# 1                41
# 2                45
# 3                45
# 4                37
# ..              ...
# 927              37
# 928              45
# 929              37
# 930              29
# 931              37
#
# [932 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.plot(x='Year', y='Events_by_year', kind='scatter', title='Fireball Event Scatter Plot')
# Out:
# <AxesSubplot:title={'center':'Fireball Event Scatter Plot'}, xlabel='Year', ylabel='Events_by_year'>

# %%
#Test train split for supervised training
X_train, X_test, y_train, y_test = train_test_split(df.Year, df.Events_by_year)

# %%
#Test train split visualizaiton 
plt.scatter(X_train, y_train, label='Training Data', marker = 's', color='r', alpha=.7)
plt.scatter(X_test, y_test, label='Testing Data', color='y', alpha=.7)
plt.legend()
plt.title('Test Train split for Fireball Prediction')
plt.xlabel('Year')
plt.ylabel('Events per year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Create linear model and train it
LR=LinearRegression()
LR.fit(X_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
#use model to predict on TEST data
prediction = LR.predict(X_test.values.reshape(-1,1))

#plot prediction line againt actual test data
plt.plot(X_test,prediction, label='Linear Regression', color ='b')
plt.scatter(X_test, y_test, label ='Actual Test Data', color ='y', alpha=.7)
plt.xlabel('Year')
plt.ylabel('Events per year')
plt.title('Machine Learning Model for Fireball Prediction')
plt.legend()
plt.show()

# %%
#Predict fireball event in 2022
LR.predict(np.array([[2022]]))[0]
# Out:
# 38.98225371423189

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test, prediction)
# Out:
# 5.837963433839777

# %%
metrics.mean_squared_error(y_test, prediction)
# Out:
# 55.447297664542326

# %%
df
# Out:
#     Peak Brightness Date/Time (UT) Latitude (deg.) Longitude (deg.)  \
# 0              2022-09-04 03:54:55           20.0N           165.9E
# 1              2020-01-17 21:29:49           19.4N            66.0W
# 2              2005-05-07 09:31:44           75.8S           163.7E
# 3              2005-10-26 21:30:47           36.3S            80.5W
# 4              2003-04-13 17:58:41           14.8N            64.5E
# ..                             ...             ...              ...
# 927            2006-04-25 18:46:53             NaN              NaN
# 928            2005-04-16 10:40:38             NaN              NaN
# 929            2003-09-21 07:40:00             NaN              NaN
# 930            2002-03-18 14:44:57           60.4S           120.5W
# 931            2000-06-23 09:03:42           69.2N            44.0W
#
#      Altitude (km)  Velocity (km/s)  Total Radiated Energy (J)  \
# 0             14.0             21.9               2.400000e+10
# 1             14.5             15.5               9.700000e+10
# 2             15.2             16.6               2.600000e+10
# 3             16.7              NaN               1.380000e+11
# 4             17.0              NaN               1.750000e+11
# ..             ...              ...                        ...
# 927            NaN              NaN               2.000000e+10
# 928            NaN              NaN               2.000000e+10
# 929            NaN              NaN               2.000000e+10
# 930            NaN              NaN               2.000000e+10
# 931            NaN              NaN               2.000000e+10
#
#      Calculated Total Impact Energy (kt)  Log Impact Energy  Year  \
# 0                                  0.086          -2.453408  2022
# 1                                  0.290          -1.237874  2020
# 2                                  0.092          -2.385967  2005
# 3                                  0.400          -0.916291  2005
# 4                                  0.500          -0.693147  2003
# ..                                   ...                ...   ...
# 927                                0.073          -2.617296  2006
# 928                                0.073          -2.617296  2005
# 929                                0.073          -2.617296  2003
# 930                                0.073          -2.617296  2002
# 931                                0.073          -2.617296  2000
#
#      Events_by_year
# 0                34
# 1                41
# 2                45
# 3                45
# 4                37
# ..              ...
# 927              37
# 928              45
# 929              37
# 930              29
# 931              37
#
# [932 rows x 10 columns]

# %%
df.hist(column='Log Impact Energy', bins=[-3,-2,-1,0,1,2,3])
plt.title('Frequency of Impact Energy')
plt.xlabel('Log of Impact Energy (kt)')
plt.ylabel('Number of Fireballs')
# Out:
# Text(0, 0.5, 'Number of Fireballs')

# %%
del df['Latitude (deg.)']
del df['Longitude (deg.)']
del df['Altitude (km)']

# %%
df
# Out:
#     Peak Brightness Date/Time (UT)  Velocity (km/s)  \
# 0              2022-09-04 03:54:55             21.9
# 1              2020-01-17 21:29:49             15.5
# 2              2005-05-07 09:31:44             16.6
# 3              2005-10-26 21:30:47              NaN
# 4              2003-04-13 17:58:41              NaN
# ..                             ...              ...
# 927            2006-04-25 18:46:53              NaN
# 928            2005-04-16 10:40:38              NaN
# 929            2003-09-21 07:40:00              NaN
# 930            2002-03-18 14:44:57              NaN
# 931            2000-06-23 09:03:42              NaN
#
#      Total Radiated Energy (J)  Calculated Total Impact Energy (kt)  \
# 0                 2.400000e+10                                0.086
# 1                 9.700000e+10                                0.290
# 2                 2.600000e+10                                0.092
# 3                 1.380000e+11                                0.400
# 4                 1.750000e+11                                0.500
# ..                         ...                                  ...
# 927               2.000000e+10                                0.073
# 928               2.000000e+10                                0.073
# 929               2.000000e+10                                0.073
# 930               2.000000e+10                                0.073
# 931               2.000000e+10                                0.073
#
#      Log Impact Energy  Year  Events_by_year
# 0            -2.453408  2022              34
# 1            -1.237874  2020              41
# 2            -2.385967  2005              45
# 3            -0.916291  2005              45
# 4            -0.693147  2003              37
# ..                 ...   ...             ...
# 927          -2.617296  2006              37
# 928          -2.617296  2005              45
# 929          -2.617296  2003              37
# 930          -2.617296  2002              29
# 931          -2.617296  2000              37
#
# [932 rows x 7 columns]

# %%
del df['Total Radiated Energy (J)']
del df['Velocity (km/s)']

# %%
df
# Out:
#     Peak Brightness Date/Time (UT)  Calculated Total Impact Energy (kt)  \
# 0              2022-09-04 03:54:55                                0.086
# 1              2020-01-17 21:29:49                                0.290
# 2              2005-05-07 09:31:44                                0.092
# 3              2005-10-26 21:30:47                                0.400
# 4              2003-04-13 17:58:41                                0.500
# ..                             ...                                  ...
# 927            2006-04-25 18:46:53                                0.073
# 928            2005-04-16 10:40:38                                0.073
# 929            2003-09-21 07:40:00                                0.073
# 930            2002-03-18 14:44:57                                0.073
# 931            2000-06-23 09:03:42                                0.073
#
#      Log Impact Energy  Year  Events_by_year
# 0            -2.453408  2022              34
# 1            -1.237874  2020              41
# 2            -2.385967  2005              45
# 3            -0.916291  2005              45
# 4            -0.693147  2003              37
# ..                 ...   ...             ...
# 927          -2.617296  2006              37
# 928          -2.617296  2005              45
# 929          -2.617296  2003              37
# 930          -2.617296  2002              29
# 931          -2.617296  2000              37
#
# [932 rows x 5 columns]

# %%
del df['Calculated Total Impact Energy (kt)']
del df['Log Impact Energy']

# %%
del df['Peak Brightness Date/Time (UT)']

# %%
df
# Out:
#      Year  Events_by_year
# 0    2022              34
# 1    2020              41
# 2    2005              45
# 3    2005              45
# 4    2003              37
# ..    ...             ...
# 927  2006              37
# 928  2005              45
# 929  2003              37
# 930  2002              29
# 931  2000              37
#
# [932 rows x 2 columns]

# %%
#delete rows with 2022
df.drop(df.index[df['Year'] == 2022], inplace=True)
df
# Out:
#      Year  Events_by_year
# 1    2020              41
# 2    2005              45
# 3    2005              45
# 4    2003              37
# 5    2014              33
# ..    ...             ...
# 927  2006              37
# 928  2005              45
# 929  2003              37
# 930  2002              29
# 931  2000              37
#
# [898 rows x 2 columns]

# %%
#Total fireball events by year from 1988 to 2022
#plot coount of year in bar graph
df.groupby('Year').count().plot(kind='bar')
plt.ylabel('Counts')
plt.title('Total Fireball Events Per Year')
plt.savefig("Total Fireball Events Per Year.png")
